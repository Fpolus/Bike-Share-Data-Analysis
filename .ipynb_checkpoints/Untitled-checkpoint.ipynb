# %%
import pandas as pd

# %%
bike_data = pd.read_csv('resources/NYC-CitiBike-2016.csv')
bike_data
# Out:
#         tripduration         starttime          stoptime  start station id  \
# 0                839     1/1/2016 0:09     1/1/2016 0:23               532
# 1                686     1/1/2016 0:21     1/1/2016 0:32              3143
# 2                315     1/1/2016 0:33     1/1/2016 0:38              3164
# 3                739     1/1/2016 0:40     1/1/2016 0:53               223
# 4               1253     1/1/2016 0:44     1/1/2016 1:05               484
# ...              ...               ...               ...               ...
# 276793           295  12/31/2016 22:39  12/31/2016 22:44               484
# 276794           277  12/31/2016 22:52  12/31/2016 22:57               168
# 276795           601  12/31/2016 23:14  12/31/2016 23:24              3295
# 276796          2102  12/31/2016 23:32     1/1/2017 0:07              3077
# 276797          1258  12/31/2016 23:53     1/1/2017 0:14               334
#
#               start station name  start station latitude  \
# ...

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276798 entries, 0 to 276797
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             276798 non-null  int64
#  1   starttime                276798 non-null  object
#  2   stoptime                 276798 non-null  object
#  3   start station id         276798 non-null  int64
#  4   start station name       276798 non-null  object
#  5   start station latitude   276798 non-null  float64
#  6   start station longitude  276798 non-null  float64
#  7   end station id           276798 non-null  int64
#  8   end station name         276798 non-null  object
#  9   end station latitude     276798 non-null  float64
#  10  end station longitude    276798 non-null  float64
#  11  bikeid                   276798 non-null  int64
#  12  usertype                 276081 non-null  object
# ...

# %%
# separating the date and time

# first let's separate the start time and date
bike_data['date'] = pd.to_datetime(bike_data['starttime']).dt.date
bike_data['time'] = pd.to_datetime(bike_data['starttime']).dt.time

# Now we are going to separate the end time and date
bike_data['date'] = pd.to_datetime(bike_data['stoptime']).dt.date
bike_data['time'] = pd.to_datetime(bike_data['starttime']).dt.time

# %%
bike_data.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           839  1/1/2016 0:09  1/1/2016 0:23               532
# 1           686  1/1/2016 0:21  1/1/2016 0:32              3143
# 2           315  1/1/2016 0:33  1/1/2016 0:38              3164
# 3           739  1/1/2016 0:40  1/1/2016 0:53               223
# 4          1253  1/1/2016 0:44  1/1/2016 1:05               484
#
#        start station name  start station latitude  start station longitude  \
# 0         S 5 Pl & S 4 St               40.710451               -73.960876
# 1         5 Ave & E 78 St               40.776829               -73.963888
# 2  Columbus Ave & W 72 St               40.777057               -73.978985
# 3         W 13 St & 7 Ave               40.737815               -73.999947
# 4         W 44 St & 5 Ave               40.755003               -73.980144
#
#    end station id          end station name  end station latitude  \
# ...
